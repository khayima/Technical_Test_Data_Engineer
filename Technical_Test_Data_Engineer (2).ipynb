# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 

warnings.filterwarnings('ignore') #Handling warning

# %% [markdown]
# ### Display Dataset

# %%
data = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_customers_dataset.csv') #directory based on file location
data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
data['customer_state']
# Out:
# 0        SP
# 1        SP
# 2        SP
# 3        SP
# 4        SP
#          ..
# 99436    SP
# 99437    SP
# 99438    CE
# 99439    RS
# 99440    SP
# Name: customer_state, Length: 99441, dtype: object

# %%
data1 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_geolocation_dataset.csv')
data1.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
data2 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_order_items_dataset.csv')
data2.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
data3 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_order_payments_dataset.csv')
data3.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
data3['payment_type'].unique()
# Out:
# array(['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %%
data4 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_order_reviews_dataset.csv')
data4.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
data5 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_orders_dataset.csv')
data5.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
data6 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_products_dataset.csv')
data6.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
data7 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_sellers_dataset.csv')
data7.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
data8 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\product_category_name_translation.csv')
data8.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
datax = data3[data3['order_id']=='b81ef226f3fe1789b1e8b2acac839d17']
datax
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33

# %%
data4 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_order_reviews_dataset.csv')
data4.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
datay = data4[data4['order_id']=='b81ef226f3fe1789b1e8b2acac839d17']
datay
# Out:
#                               review_id                          order_id  \
# 19666  4ce650e117a5b292bf5ea980a61eb61e  b81ef226f3fe1789b1e8b2acac839d17
#
#        review_score review_comment_title  \
# 19666             1        Não recomendo
#
#                                   review_comment_message review_creation_date  \
# 19666  Produto com qualidade ruim, amassado e descasc...  2018-05-10 00:00:00
#
#       review_answer_timestamp
# 19666     2018-05-15 23:38:00

# %%
data5 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_orders_dataset.csv')
data5.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
data6 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_products_dataset.csv')
data6.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
data7 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\olist_sellers_dataset.csv')
data7.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
data8 = pd.read_csv(r'C:\Users\ASUS\Documents\Data\product_category_name_translation.csv')
data8.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# # Total Revenue

# %% [markdown]
# ### Payment_value & Order ID

# %%
payment_value = data3[['order_id','payment_value']] #Generate columns order_id & payment_value from data3
payment_value.head()
# Out:
#                            order_id  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd          65.71
# 3  ba78997921bbcdc1373bb41e913ab953         107.78
# 4  42fdf880ba16b47b59251dd489d4441a         128.45

# %% [markdown]
# ### Order Purchase Timestamp & Order ID

# %%
order_approved_at = data5[['order_id','order_approved_at']] #Gnerate columns order_id & order_approved_at from data5
order_approved_at.head()
# Out:
#                            order_id    order_approved_at
# 0  e481f51cbdc54678b7cc49136f2d6af7  2017-10-02 11:07:15
# 1  53cdb2fc8bc7dce0b6741e2150273451  2018-07-26 03:24:27
# 2  47770eb9100c2d0c44946d9cf07ec65d  2018-08-08 08:55:23
# 3  949d5b44dbf5de918fe9c16f97b45f8a  2017-11-18 19:45:59
# 4  ad21c59c0840e6cb83a9ceb5573f8159  2018-02-13 22:20:29

# %%
dt_ordrpymnt = pd.concat([payment_value, order_approved_at],axis=1) #concat pandas digunakan untuk megeksport data , axis =1 digunakan untuk menampilkan masing2 kolom pada dataframe yang diexport secara berurut
dt_ordrpymnt.to_csv("order_approved_at.csv",index=False) #index=False, digunakan untuk membuat index baru atau menghilangkan multiple index

# %% [markdown]
# ### Menggabungkan data payment_value & Order_Purchase_Timestamp Pada 1 Tabel

# %%
order = pd.merge(payment_value, order_approved_at,how='left') #left join
order.head()
# Out:
#                            order_id  payment_value    order_approved_at
# 0  b81ef226f3fe1789b1e8b2acac839d17          99.33  2018-04-25 22:15:09
# 1  a9810da82917af2d9aefd1278f1dcfa0          24.39  2018-06-26 11:18:58
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd          65.71  2017-12-14 09:52:34
# 3  ba78997921bbcdc1373bb41e913ab953         107.78  2017-12-06 12:13:20
# 4  42fdf880ba16b47b59251dd489d4441a         128.45  2018-05-21 16:14:41

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           103886 non-null  object
#  1   payment_value      103886 non-null  float64
#  2   order_approved_at  103711 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 3.2+ MB

# %%
order['order_approved_at']=pd.to_datetime(order['order_approved_at']) #object data type convertion to datetime data type

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           103886 non-null  object
#  1   payment_value      103886 non-null  float64
#  2   order_approved_at  103711 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 3.2+ MB

# %%
order['year'] = order['order_approved_at'].dt.strftime('%Y') # Split year and place it at order['year'] column
order['month'] = order['order_approved_at'].dt.strftime('%m') # Split month and place it at order['month'] column

# %%
order.head()
# Out:
#                            order_id  payment_value    order_approved_at
# 0  b81ef226f3fe1789b1e8b2acac839d17          99.33  2018-04-25 22:15:09
# 1  a9810da82917af2d9aefd1278f1dcfa0          24.39  2018-06-26 11:18:58
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd          65.71  2017-12-14 09:52:34
# 3  ba78997921bbcdc1373bb41e913ab953         107.78  2017-12-06 12:13:20
# 4  42fdf880ba16b47b59251dd489d4441a         128.45  2018-05-21 16:14:41

# %%
order_sum_year = order.groupby('year').agg({"payment_value":"sum"}).reset_index()
order_sum_year
# Out:
#    year  payment_value
# 0  2016       58400.36
# 1  2017     7227842.45
# 2  2018     8685499.54

# %%
order_sum_month = order.groupby(['month','year']).agg({"payment_value":"mean"}).reset_index()
order_sum_month.head()
# Out:
#   month  year  payment_value
# 0    01  2017     162.961520
# 1    01  2018     147.851446
# 2    02  2017     155.895417
# 3    02  2018     142.093246
# 4    03  2017     156.828625

# %%
order_sum_2016 = order[order['year']=='2016']
order_sum_2016.head()
# Out:
#                               order_id  payment_value   order_approved_at  \
# 155   3b697a20d9e427646d92567910af6d57          45.46 2016-10-06 15:50:54
# 332   c776863a93dc0740c6e7d78104b21413         264.08 2016-10-10 15:44:46
# 368   ed90ba41c41da31da8e891ff43a584d1         156.22 2016-10-07 15:59:09
# 1236  d3f7c0e804b501782903f7af749eb797         784.80 2016-10-10 14:42:00
# 1377  c8258090bca7cc6a62c1e15d7fd995d4         150.99 2016-10-09 23:48:46
#
#       year month
# 155   2016    10
# 332   2016    10
# 368   2016    10
# 1236  2016    10
# 1377  2016    10

# %%
order_sum_2016n=order_sum_2016.groupby(['year','month'])['payment_value'].sum().reset_index()
order_sum_2016n=order_sum_2016n.rename(columns={'year':'year','month':'month','payment_value':'payment_value_2016'})
order_sum_2016n
# Out:
#    year month  payment_value_2016
# 0  2016    10            58380.74
# 1  2016    12               19.62

# %%
order_sum_2016n.sort_values(by='payment_value_2016',ascending=False)
# Out:
#    year month  payment_value_2016
# 0  2016    10            58380.74
# 1  2016    12               19.62

# %%
order_sum_2016.groupby(['year','month'])['payment_value'].sum().plot(grid=True, figsize=(20,5));

plt.xticks(rotation=45);
plt.ylabel('total_revenue');
plt.title('revenue/Month On 2016');

# %%
order_sum_2017 = order[order['year']=='2017']
order_sum_2017.head()
# Out:
#                            order_id  payment_value   order_approved_at  year  \
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd          65.71 2017-12-14 09:52:34  2017
# 3  ba78997921bbcdc1373bb41e913ab953         107.78 2017-12-06 12:13:20  2017
# 6  771ee386b001f06208a7419e4fc1bbd7          81.16 2017-06-23 13:25:19  2017
# 7  3d7239c394a212faae122962df514ac7          51.84 2017-06-05 10:55:16  2017
# 9  0573b5e23cbd798006520e1d5b4c6714          51.95 2017-07-06 03:15:36  2017
#
#   month
# 2    12
# 3    12
# 6    06
# 7    06
# 9    07

# %%
order_sum_2017n=order_sum_2017.groupby(['year','month'])['payment_value'].sum().sort_values(ascending=False).reset_index()
order_sum_2017n=order_sum_2017n.rename(columns={'year':'year','month':'month','payment_value':'payment_value_2017'})
order_sum_2017n.head()
# Out:
#    year month  payment_value_2017
# 0  2017    11          1174911.51
# 1  2017    12           902534.69
# 2  2017    10           782898.61
# 3  2017    09           717821.79
# 4  2017    08           672772.79

# %%
order_sum_2017n.sort_values(by='payment_value_2017',ascending=False).head()
# Out:
#    year month  payment_value_2017
# 0  2017    11          1174911.51
# 1  2017    12           902534.69
# 2  2017    10           782898.61
# 3  2017    09           717821.79
# 4  2017    08           672772.79

# %%
order_sum_2017.groupby(['year','month'])['payment_value'].sum().plot(grid=True, figsize=(20,7));

plt.xticks(rotation=45);
plt.ylabel('total_revenue');
plt.title('revenue/Month On 2017');

# %%
order_sum_2018 = order[order['year']=='2018']
order_sum_2018.head()
# Out:
#                            order_id  payment_value   order_approved_at  year  \
# 0  b81ef226f3fe1789b1e8b2acac839d17          99.33 2018-04-25 22:15:09  2018
# 1  a9810da82917af2d9aefd1278f1dcfa0          24.39 2018-06-26 11:18:58  2018
# 4  42fdf880ba16b47b59251dd489d4441a         128.45 2018-05-21 16:14:41  2018
# 5  298fcdf1f73eb413e4d26d01b25bc1cd          96.12 2018-05-07 15:31:14  2018
# 8  1f78449c87a54faf9e96e88ba1491fa9         341.09 2018-07-23 11:32:08  2018
#
#   month
# 0    04
# 1    06
# 4    05
# 5    05
# 8    07

# %%
order_sum_2018n=order_sum_2018.groupby(['year','month'])['payment_value'].sum().sort_values(ascending=False)[:10].reset_index()
order_sum_2018n=order_sum_2018n.rename(columns={'year':'year','month':'month','payment_value':'payment_value_2018'})
order_sum_2018n.head()
# Out:
#    year month  payment_value_2018
# 0  2018    05          1180152.88
# 1  2018    03          1170383.27
# 2  2018    04          1137693.93
# 3  2018    01          1106076.67
# 4  2018    07          1043137.76

# %%
order_sum_2018n.sort_values(by='payment_value_2018',ascending=False).head()
# Out:
#    year month  payment_value_2018
# 0  2018    05          1180152.88
# 1  2018    03          1170383.27
# 2  2018    04          1137693.93
# 3  2018    01          1106076.67
# 4  2018    07          1043137.76

# %%
order_sum_2018.groupby(['year','month'])['payment_value'].sum().plot(grid=True, figsize=(20,5));

plt.xticks(rotation=45);
plt.ylabel('total_revenue');
plt.title('revenue/Month On 2018');

# %%
order.groupby(['year','month'])['payment_value'].sum().plot(figsize=(20,7),grid=True)
# Out:
# <AxesSubplot:xlabel='year,month'>

# %% [markdown]
# # Market Trends

# %%
dt_product = data2[['order_id','product_id']] 
dt_product.head()
# Out:
#                            order_id                        product_id
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089

# %%
dt_customer = data5[['order_id','customer_id','order_approved_at']] #Menampilkan isian kolom order_id dan payment_value dari data olist_order_payment_dataset
dt_customer.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#      order_approved_at
# 0  2017-10-02 11:07:15
# 1  2018-07-26 03:24:27
# 2  2018-08-08 08:55:23
# 3  2017-11-18 19:45:59
# 4  2018-02-13 22:20:29

# %%
dt_procstm = pd.concat([dt_product, dt_customer],axis=1) #concat pandas digunakan untuk megeksport data , axis =1 digunakan untuk menampilkan masing2 kolom pada dataframe yang diexport secara berurut
dt_procstm.to_csv("procustomer.csv",index=False) #index=False, digunakan untuk membuat index baru atau menghilangkan multiple index

# %%
procstm = pd.merge(dt_product, dt_customer,how='left')
procstm.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                         customer_id    order_approved_at
# 0  3ce436f183e68e07877b285a838db11a  2017-09-13 09:45:35
# 1  f6dd3ec061db4e3987629fe6b26e5cce  2017-04-26 11:05:13
# 2  6489ae5e4333f3693df5ad4372dab6d3  2018-01-14 14:48:30
# 3  d4eb9395c8c0431ee92fce09860c5a06  2018-08-08 10:10:18
# 4  58dbd0b2d70206bf40e62cd34e84d795  2017-02-04 14:10:13

# %%
dt_procstm_spec = pd.concat([procstm, data6],axis=1) #concat pandas digunakan untuk megeksport data , axis =1 digunakan untuk menampilkan masing2 kolom pada dataframe yang diexport secara berurut
dt_procstm_spec.to_csv("procustomer_spec.csv",index=False) #index=False, digunakan untuk membuat index baru atau menghilangkan multiple index

# %%
procstm_specjoin = pd.merge(procstm, data6,how='left')
procstm_specjoin.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                         customer_id    order_approved_at  \
# 0  3ce436f183e68e07877b285a838db11a  2017-09-13 09:45:35
# 1  f6dd3ec061db4e3987629fe6b26e5cce  2017-04-26 11:05:13
# 2  6489ae5e4333f3693df5ad4372dab6d3  2018-01-14 14:48:30
# 3  d4eb9395c8c0431ee92fce09860c5a06  2018-08-08 10:10:18
# 4  58dbd0b2d70206bf40e62cd34e84d795  2017-02-04 14:10:13
#
#   product_category_name  product_name_lenght  product_description_lenght  \
# 0            cool_stuff                 58.0                       598.0
# ...

# %%
dt_procstm_new = pd.concat([procstm_specjoin, data8],axis=1) #concat pandas digunakan untuk megeksport data , axis =1 digunakan untuk menampilkan masing2 kolom pada dataframe yang diexport secara berurut
dt_procstm_new.to_csv("procustomer_new.csv",index=False) #index=False, digunakan untuk membuat index baru atau menghilangkan multiple index

# %%
procstm_specjoin_new = pd.merge(procstm_specjoin, data8,how='left')
procstm_specjoin_new.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                         customer_id    order_approved_at  \
# 0  3ce436f183e68e07877b285a838db11a  2017-09-13 09:45:35
# 1  f6dd3ec061db4e3987629fe6b26e5cce  2017-04-26 11:05:13
# 2  6489ae5e4333f3693df5ad4372dab6d3  2018-01-14 14:48:30
# 3  d4eb9395c8c0431ee92fce09860c5a06  2018-08-08 10:10:18
# 4  58dbd0b2d70206bf40e62cd34e84d795  2017-02-04 14:10:13
#
#   product_category_name  product_name_lenght  product_description_lenght  \
# 0            cool_stuff                 58.0                       598.0
# ...

# %%
procstm_specjoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    112650 non-null  object
#  1   product_id                  112650 non-null  object
#  2   customer_id                 112650 non-null  object
#  3   order_approved_at           112635 non-null  object
#  4   product_category_name       111047 non-null  object
#  5   product_name_lenght         111047 non-null  float64
#  6   product_description_lenght  111047 non-null  float64
#  7   product_photos_qty          111047 non-null  float64
#  8   product_weight_g            112632 non-null  float64
#  9   product_length_cm           112632 non-null  float64
#  10  product_height_cm           112632 non-null  float64
#  11  product_width_cm            112632 non-null  float64
# dtypes: float64(7), object(5)
# ...

# %%
procstm_specjoin_new['order_approved_at']=pd.to_datetime(order['order_approved_at'])

# %%
procstm_specjoin_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   product_id                     112650 non-null  object
#  2   customer_id                    112650 non-null  object
#  3   order_approved_at              103711 non-null  datetime64[ns]
#  4   product_category_name          111047 non-null  object
#  5   product_name_lenght            111047 non-null  float64
#  6   product_description_lenght     111047 non-null  float64
#  7   product_photos_qty             111047 non-null  float64
#  8   product_weight_g               112632 non-null  float64
#  9   product_length_cm              112632 non-null  float64
#  10  product_height_cm              112632 non-null  float64
#  11  product_width_cm               112632 non-null  float64
# ...

# %%
procstm_specjoin_new['year'] = procstm_specjoin_new['order_approved_at'].dt.strftime('%Y')
procstm_specjoin_new['month'] = procstm_specjoin_new['order_approved_at'].dt.strftime('%m')

# %%
procstm_specjoin_new.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                         customer_id   order_approved_at product_category_name  \
# 0  3ce436f183e68e07877b285a838db11a 2018-04-25 22:15:09            cool_stuff
# 1  f6dd3ec061db4e3987629fe6b26e5cce 2018-06-26 11:18:58              pet_shop
# 2  6489ae5e4333f3693df5ad4372dab6d3 2017-12-14 09:52:34      moveis_decoracao
# 3  d4eb9395c8c0431ee92fce09860c5a06 2017-12-06 12:13:20            perfumaria
# 4  58dbd0b2d70206bf40e62cd34e84d795 2018-05-21 16:14:41    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# ...

# %%
product_sale_2016 = procstm_specjoin_new[procstm_specjoin_new['year']=='2016']
product_sale_2016.head()
# Out:
#                               order_id                        product_id  \
# 155   005f25968fc854ea16fb16f5bdbc87c7  f9259c9e7c0f12c70f7a81409680a5ff
# 332   00ce92d57f4f9a112bdb8a2a283e5f97  d1c427060a0f73f6b889a5c7c61f2ac4
# 368   00e5b655df1cc911466758210325c67c  880be32f4db1d9f6e2bec38fb6ac23ab
# 1236  02e0b68852217f5715fb9cc885829454  2028bf1b01cafb2d2b1901fca4083222
# 1377  03347815dd6e37a668b3954401838318  ab37272e0676ac205aba0db310cfaaa0
#
#                            customer_id   order_approved_at  \
# 155   837cf66598995d5f51efd00d99ced139 2016-10-06 15:50:54
# 332   9c1e141643cc2c164c2fa7c7140f5317 2016-10-10 15:44:46
# 368   7f2a66ad36459534aeadd9b1985bef2b 2016-10-07 15:59:09
# 1236  12b78d9eacb77edde80d19b9528bcfe9 2016-10-10 14:42:00
# 1377  a3a4dcea8bf35b152eb89c42e403f258 2016-10-09 23:48:46
#
#        product_category_name  product_name_lenght  product_description_lenght  \
# 155            esporte_lazer                 45.0                       407.0
# ...

# %%
product_sale_2016.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count           334.000000                  334.000000          334.000000
# mean             49.739521                  799.955090            2.077844
# std               9.654441                  675.232031            1.632971
# min              21.000000                   70.000000            1.000000
# 25%              44.000000                  348.000000            1.000000
# 50%              53.000000                  636.000000            1.000000
# 75%              57.000000                  972.500000            3.000000
# max              63.000000                 3831.000000           11.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count        339.000000         339.000000         339.000000
# mean        2323.589971          30.825959          17.831858
# std         4375.307829          15.471173          14.746519
# ...

# %% [markdown]
# ## Market Data 2016

# %% [markdown]
# ### Total Product Sale/Month On 2016

# %%
product_sale_2016 [['month','year','product_category_name_english']].head()
# Out:
#      month  year product_category_name_english
# 155     10  2016                sports_leisure
# 332     10  2016         computers_accessories
# 368     10  2016                          toys
# 1236    10  2016                     perfumery
# 1377    10  2016                sports_leisure

# %%
dt_product_sale_2016 =pd.DataFrame(product_sale_2016.groupby("month")['product_category_name_english'].count())
dt_product_sale_2016.head()
# Out:
#        product_category_name_english
# month
# 10                               333
# 12                                 1

# %%
product_sale_2016.groupby("month")['product_category_name_english'].count().sort_values(ascending=False).plot.bar();

plt.ylabel("Total Product Sale");
plt.title("Total Product Sale/Month On 2016");

# %% [markdown]
# ### Product Highest Sale Frequency On 2016

# %%
import statistics
produk_best_seller2016=statistics.mode(product_sale_2016['product_category_name_english'])
produk_best_seller2016
# Out:
# 'health_beauty'

# %%
beleza=product_sale_2016 [product_sale_2016['product_category_name_english']=='health_beauty']
beleza.head()

beleza.groupby(['month'])['product_category_name_english'].count().plot.bar();

plt.ylabel('Total Product Sale');
plt.title('health_beauty Sale/Month On 2017');

# %% [markdown]
# ### Trend Product Category Sale/Month On 2016

# %%
market_2016 = pd.DataFrame(product_sale_2016.groupby(["month","product_category_name_english"])['product_id'].count())
market_2016 = market_2016.rename(columns={'month':'month','product_category_name_english':'product_category_name_english','product_id':'total_product'})
market_2016.head()
# Out:
#                                      total_product
# month product_category_name_english
# 10    auto                                      11
#       baby                                       8
#       bed_bath_table                            31
#       books_general_interest                     1
#       books_technical                            2

# %%
market_pvt2016=market_2016.reset_index().pivot('month','product_category_name_english').fillna(0)
market_pvt2016
# Out:
#                               total_product                      \
# product_category_name_english          auto baby bed_bath_table
# month
# 10                                     11.0  8.0           31.0
# 12                                      0.0  0.0            0.0
#
#                                                                       \
# product_category_name_english books_general_interest books_technical
# month
# 10                                               1.0             2.0
# 12                                               0.0             0.0
#
#                                                                               \
# product_category_name_english computers computers_accessories consoles_games
# month
# 10                                  1.0                  21.0            8.0
# 12                                  0.0                   0.0            0.0
#
#                                                                \
# ...

# %%
market_pvt2016= market_pvt2016.droplevel(level = 0, axis=1)
market_pvt2016
# Out:
# product_category_name_english  auto  baby  bed_bath_table  \
# month
# 10                             11.0   8.0            31.0
# 12                              0.0   0.0             0.0
#
# product_category_name_english  books_general_interest  books_technical  \
# month
# 10                                                1.0              2.0
# 12                                                0.0              0.0
#
# product_category_name_english  computers  computers_accessories  \
# month
# 10                                   1.0                   21.0
# 12                                   0.0                    0.0
#
# product_category_name_english  consoles_games  \
# month
# 10                                        8.0
# 12                                        0.0
#
# product_category_name_english  construction_tools_construction  \
# month
# 10                                                         1.0
# 12                                                         0.0
# ...

# %%
market_pvt2016.plot(figsize=(20,20),grid=True);

plt.ylabel('Total Product Sale');
plt.title('Product Categor Sale/Month On 2016');

# %% [markdown]
# ### Product High Sale Frequency On 2017

# %%
product_sale_2017 = procstm_specjoin_new[procstm_specjoin_new['year']=='2017']
product_sale_2017 
product_sale_2017 [['month','year','product_category_name_english']]
product_sale_2017.groupby("month")['product_category_name_english'].count().sort_values(ascending=False).plot.bar();

plt.ylabel('Total_Product_Sale');
plt.title('Total Product Sale/Month On 2017');

# %%
produk_best_seller2017=statistics.mode(product_sale_2017['product_category_name_english'])
produk_best_seller2017
# Out:
# 'bed_bath_table'

# %%
cama=product_sale_2017 [product_sale_2017['product_category_name_english']=='bed_bath_table']
cama.head()

cama.groupby('month')['product_category_name_english'].count().sort_values(ascending=False).plot.bar();
plt.ylabel('Total_Product_Sale');
plt.title('bed_bath_table Sale/Month On 2017');

# %% [markdown]
# ### Trend Product Category Sale/Month On 2017

# %%
market_2017 = pd.DataFrame(product_sale_2017.groupby(["month","product_category_name_english"])['product_id'].count())
market_2017
# Out:
#                                      product_id
# month product_category_name_english
# 01    agro_industry_and_commerce              1
#       air_conditioning                        6
#       arts_and_craftmanship                   1
#       audio                                   1
#       auto                                   33
# ...                                         ...
# 12    stationery                            132
#       tablets_printing_image                  9
#       telephony                             238
#       toys                                  212
#       watches_gifts                         302
#
# [752 rows x 1 columns]

# %%
market_2017 = market_2017.rename(columns={'month':'month','product_category_name_english':'product_category_name_english','product_id':'total_product'})
market_2017.head()
# Out:
#                                      total_product
# month product_category_name_english
# 01    agro_industry_and_commerce                 1
#       air_conditioning                           6
#       arts_and_craftmanship                      1
#       audio                                      1
#       auto                                      33

# %%
market_pvt2017=market_2017.reset_index().pivot('month','product_category_name_english').fillna(0)
market_pvt2017.head()
# Out:
#                                            total_product                   \
# product_category_name_english agro_industry_and_commerce air_conditioning
# month
# 01                                                   1.0              6.0
# 02                                                   4.0              4.0
# 03                                                   6.0             11.0
# 04                                                   4.0              4.0
# 05                                                   4.0             12.0
#
#                                                                               \
# product_category_name_english  art arts_and_craftmanship audio   auto   baby
# month
# 01                             0.0                   1.0   1.0   33.0   28.0
# 02                             5.0                   0.0   8.0   72.0   65.0
# 03                             5.0                   1.0  10.0  107.0   82.0
# ...

# %%
market_pvt2017= market_pvt2017.droplevel(level = 0, axis=1)
market_pvt2017.head()
# Out:
# product_category_name_english  agro_industry_and_commerce  air_conditioning  \
# month
# 01                                                    1.0               6.0
# 02                                                    4.0               4.0
# 03                                                    6.0              11.0
# 04                                                    4.0               4.0
# 05                                                    4.0              12.0
#
# product_category_name_english  art  arts_and_craftmanship  audio   auto  \
# month
# 01                             0.0                    1.0    1.0   33.0
# 02                             5.0                    0.0    8.0   72.0
# 03                             5.0                    1.0   10.0  107.0
# 04                             5.0                    1.0   15.0   85.0
# 05                             9.0                    1.0    6.0  149.0
#
# ...

# %%
market_pvt2017.plot(figsize=(20,20),grid=True)

plt.ylabel('Total Product Sale');
plt.title('Product Categor Sale/Month On 2017');

# %% [markdown]
# ### Product High Sale Frequency On 2018

# %%
product_sale_2018 = procstm_specjoin_new[procstm_specjoin_new['year']=='2018']
product_sale_2018 
product_sale_2018 [['month','year','product_category_name_english']]
product_sale_2018.groupby("month")['product_category_name_english'].count().sort_values(ascending=False).plot.bar();

# %%
produk_best_seller2018=statistics.mode(product_sale_2018['product_category_name_english'])
produk_best_seller2018
# Out:
# 'bed_bath_table'

# %%
cama=product_sale_2018[product_sale_2018['product_category_name_english']=='bed_bath_table']
cama.head()

cama.groupby('month')['product_category_name_english'].count().sort_values(ascending=False).plot.bar();
plt.ylabel('Total_Product_Sale');
plt.title('bed_bath_table Sale/Month On 2018');

# %% [markdown]
# ### Trend Product Category Sale/Month On 2018

# %%
market_2018 = pd.DataFrame(product_sale_2018.groupby(["month","product_category_name_english"])['product_id'].count())
market_2018.head()
# Out:
#                                      product_id
# month product_category_name_english
# 01    agro_industry_and_commerce             14
#       air_conditioning                       21
#       art                                    13
#       audio                                  24
#       auto                                  271

# %%
market_2018 = market_2018.rename(columns={'month':'month','product_category_name_english':'product_category_name_english','product_id':'total_product'})
market_2018.head()
# Out:
#                                      total_product
# month product_category_name_english
# 01    agro_industry_and_commerce                14
#       air_conditioning                          21
#       art                                       13
#       audio                                     24
#       auto                                     271

# %%
market_2018=market_2018.reset_index().pivot('month','product_category_name_english').fillna(0)
market_2018.head()
# Out:
#                                               product_id                   \
# product_category_name_english agro_industry_and_commerce air_conditioning
# month
# 01                                                  14.0             21.0
# 02                                                  17.0             25.0
# 03                                                  23.0             14.0
# 04                                                  12.0             11.0
# 05                                                  11.0             26.0
#
#                                                                                \
# product_category_name_english   art arts_and_craftmanship audio   auto   baby
# month
# 01                             13.0                   0.0  24.0  271.0  210.0
# 02                             12.0                   0.0  30.0  248.0  179.0
# 03                             13.0                   2.0  28.0  270.0  220.0
# ...

# %%
market_2018= market_2018.droplevel(level = 0, axis=1)
market_2018.head()
# Out:
# product_category_name_english  agro_industry_and_commerce  air_conditioning  \
# month
# 01                                                   14.0              21.0
# 02                                                   17.0              25.0
# 03                                                   23.0              14.0
# 04                                                   12.0              11.0
# 05                                                   11.0              26.0
#
# product_category_name_english   art  arts_and_craftmanship  audio   auto  \
# month
# 01                             13.0                    0.0   24.0  271.0
# 02                             12.0                    0.0   30.0  248.0
# 03                             13.0                    2.0   28.0  270.0
# 04                             14.0                    2.0   31.0  260.0
# 05                             14.0                    0.0   24.0  286.0
#
# ...

# %%
market_2018.plot(figsize=(20,20),grid=True)

plt.ylabel('Total Product Sale');
plt.title('Product Categor Sale/Month On 2018');

# %% [markdown]
# ## Customer Product

# %%
procstm_specjoin_new.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                         customer_id   order_approved_at product_category_name  \
# 0  3ce436f183e68e07877b285a838db11a 2018-04-25 22:15:09            cool_stuff
# 1  f6dd3ec061db4e3987629fe6b26e5cce 2018-06-26 11:18:58              pet_shop
# 2  6489ae5e4333f3693df5ad4372dab6d3 2017-12-14 09:52:34      moveis_decoracao
# 3  d4eb9395c8c0431ee92fce09860c5a06 2017-12-06 12:13:20            perfumaria
# 4  58dbd0b2d70206bf40e62cd34e84d795 2018-05-21 16:14:41    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# ...

# %% [markdown]
# ### Product Favorite 2016

# %%
cstmreorder_2016 = pd.DataFrame(product_sale_2016.groupby(["month","product_category_name_english"])['customer_id'].count().reset_index())
cstmreorder_2016 = cstmreorder_2016.rename(columns={"month":"month","product_category_name_english":"product_category_name_english","customer_id":"total_buyer"})
cstmreorder_2016.head()
# Out:
#   month product_category_name_english  total_buyer
# 0    10                          auto           11
# 1    10                          baby            8
# 2    10                bed_bath_table           31
# 3    10        books_general_interest            1
# 4    10               books_technical            2

# %%
cstmreorder_2016_tbltot = cstmreorder_2016.groupby(['product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].reset_index()
cstmreorder_2016_tbltot.head()
# Out:
#   product_category_name_english  total_buyer
# 0                 health_beauty           32
# 1                bed_bath_table           31
# 2               furniture_decor           30
# 3                sports_leisure           27
# 4                 watches_gifts           22

# %%
cstmreorder_2016_tbltot_PerMonth = cstmreorder_2016.groupby(['month','product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].reset_index()
cstmreorder_2016_tbltot_PerMonth.head()
# Out:
#   month product_category_name_english  total_buyer
# 0    10                 health_beauty           32
# 1    10                bed_bath_table           31
# 2    10               furniture_decor           30
# 3    10                sports_leisure           27
# 4    10                 watches_gifts           22

# %%
cstmreorder_2016.groupby(['product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(10,5))

plt.xticks(rotation=70);
plt.ylabel('Total Buyer');
plt.title('10 Product Favorite On 2016');
plt.tight_layout();

# %%
cstmreorder_2016.groupby(['month','product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(10,5))

plt.xticks(rotation=70)
plt.ylabel('Total Buyer');
plt.title('10 Product Favorite/Month On 2016');
plt.tight_layout()

# %% [markdown]
# ### Product Favorite 2017

# %%
cstmreorder_2017 = pd.DataFrame(product_sale_2017.groupby(["month","product_category_name_english"])['customer_id'].count().reset_index())
cstmreorder_2017.head()
# Out:
#   month product_category_name_english  customer_id
# 0    01    agro_industry_and_commerce            1
# 1    01              air_conditioning            6
# 2    01         arts_and_craftmanship            1
# 3    01                         audio            1
# 4    01                          auto           33

# %%
cstmreorder_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 752 entries, 0 to 751
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   month                          752 non-null    object
#  1   product_category_name_english  752 non-null    object
#  2   customer_id                    752 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 17.8+ KB

# %%
cstmreorder_2017 = pd.DataFrame(product_sale_2017.groupby(["month","product_category_name_english"])['customer_id'].count().reset_index())
cstmreorder_2017 = cstmreorder_2017.rename(columns={"month":"month","product_category_name_english":"product_category_name_english","customer_id":"total_buyer"})
cstmreorder_2017.head()
# Out:
#   month product_category_name_english  total_buyer
# 0    01    agro_industry_and_commerce            1
# 1    01              air_conditioning            6
# 2    01         arts_and_craftmanship            1
# 3    01                         audio            1
# 4    01                          auto           33

# %%
cstmreorder_2017_tbltot = cstmreorder_2017.groupby(['product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].reset_index()
cstmreorder_2017_tbltot.head()
# Out:
#   product_category_name_english  total_buyer
# 0                bed_bath_table         4696
# 1                 health_beauty         4054
# 2                sports_leisure         3566
# 3               furniture_decor         3498
# 4         computers_accessories         3357

# %%
cstmreorder_2017_tbltot_PerMonth = cstmreorder_2017.groupby(['month','product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].reset_index()
cstmreorder_2017_tbltot_PerMonth.head()
# Out:
#   month product_category_name_english  total_buyer
# 0    11                bed_bath_table          736
# 1    11                 health_beauty          654
# 2    12                bed_bath_table          591
# 3    11                sports_leisure          586
# 4    11               furniture_decor          577

# %%
cstmreorder_2017.groupby(['product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(10,5))

plt.xticks(rotation=70)
plt.ylabel('Total Buyer');
plt.title('10 Product Favorite On 2017');
plt.tight_layout();

# %%
cstmreorder_2017.groupby(['month','product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(10,5))

plt.xticks(rotation=70)
plt.ylabel('Total Buyer');
plt.title('10 Product Favorite/Month On 2017');
plt.tight_layout();

# %% [markdown]
# ### Product Favorite 2018

# %%
cstmreorder_2018 = pd.DataFrame(product_sale_2018.groupby(["month","product_category_name_english"])['customer_id'].count().reset_index())
cstmreorder_2018 = cstmreorder_2018.rename(columns={"month":"month","product_category_name_english":"product_category_name_english","customer_id":"total_buyer"})
cstmreorder_2018.head()
# Out:
#   month product_category_name_english  total_buyer
# 0    01    agro_industry_and_commerce           14
# 1    01              air_conditioning           21
# 2    01                           art           13
# 3    01                         audio           24
# 4    01                          auto          271

# %%
cstmreorder_2018_tbltot = cstmreorder_2018.groupby(['product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].reset_index()
cstmreorder_2018_tbltot.head()
# Out:
#   product_category_name_english  total_buyer
# 0                bed_bath_table         5498
# 1                 health_beauty         4801
# 2                sports_leisure         4284
# 3               furniture_decor         4147
# 4         computers_accessories         3808

# %%
cstmreorder_2018.groupby(['product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(10,5))

plt.xticks(rotation=70)
plt.ylabel('Total Buyer');
plt.title('10 Product Favorite On 2018');
plt.tight_layout()

# %%
cstmreorder_2018_tbltot_PerMonth = cstmreorder_2018.groupby(['month','product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].reset_index()
cstmreorder_2018_tbltot_PerMonth.head()
# Out:
#   month product_category_name_english  total_buyer
# 0    03                bed_bath_table          735
# 1    02                bed_bath_table          734
# 2    05                bed_bath_table          720
# 3    01                bed_bath_table          714
# 4    08                bed_bath_table          691

# %%
cstmreorder_2018.groupby(['month','product_category_name_english'])['total_buyer'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(10,5))

plt.xticks(rotation=70)
plt.ylabel('Total Buyer');
plt.title('10 Product Favorite/Month On 2018');
plt.tight_layout()

# %% [markdown]
# # User Demographic

# %%
data5.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
dt_cc = data[['customer_id','customer_city']]
dt_cc.head()
# Out:
#                         customer_id          customer_city
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                 franca
# 1  18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo
# 2  4e7b3e00288586ebd08712fdd0374a03              sao paulo
# 3  b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes
# 4  4f2d8ab171c80ec8364f7c12e35b23ad               campinas

# %%
dt_ccy = data5[['customer_id','order_approved_at']]
dt_ccy.head()
# Out:
#                         customer_id    order_approved_at
# 0  9ef432eb6251297304e76186b10a928d  2017-10-02 11:07:15
# 1  b0830fb4747a6c6d20dea0b8c802d7ef  2018-07-26 03:24:27
# 2  41ce2a54c0b03bf3443c3d931a367089  2018-08-08 08:55:23
# 3  f88197465ea7920adcdbec7375364d82  2017-11-18 19:45:59
# 4  8ab97904e6daea8866dbdbc4fb7aad2c  2018-02-13 22:20:29

# %%
dt_ccyear = pd.concat([dt_cc, dt_ccy],axis=1) #concat pandas digunakan untuk megeksport data , axis =1 digunakan untuk menampilkan masing2 kolom pada dataframe yang diexport secara berurut
dt_ccyear.to_csv("dt_ccyear.csv",index=False) #index=False, digunakan untuk membuat index baru atau menghilangkan multiple index

# %%
dt_ccyear = pd.merge(dt_cc, dt_ccy,how='left') #left join
dt_ccyear.head()
# Out:
#                         customer_id          customer_city  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                 franca
# 1  18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo
# 2  4e7b3e00288586ebd08712fdd0374a03              sao paulo
# 3  b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes
# 4  4f2d8ab171c80ec8364f7c12e35b23ad               campinas
#
#      order_approved_at
# 0  2017-05-16 15:22:12
# 1  2018-01-12 20:58:32
# 2  2018-05-20 16:19:10
# 3  2018-03-13 17:29:19
# 4  2018-07-29 10:10:09

# %%
dt_ccyear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        99441 non-null  object
#  1   customer_city      99441 non-null  object
#  2   order_approved_at  99281 non-null  object
# dtypes: object(3)
# memory usage: 3.0+ MB

# %%
dt_ccyear['order_approved_at']=pd.to_datetime(dt_ccyear['order_approved_at']) #object data type convertion to datetime data type

# %%
dt_ccyear['year'] = dt_ccyear['order_approved_at'].dt.strftime('%Y') # Split year and place it at order['year'] column
dt_ccyear['month'] = dt_ccyear['order_approved_at'].dt.strftime('%m') # Split month and place it at order['month'] column

# %%
dt_ccyear.head()
# Out:
#                         customer_id          customer_city  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                 franca
# 1  18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo
# 2  4e7b3e00288586ebd08712fdd0374a03              sao paulo
# 3  b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes
# 4  4f2d8ab171c80ec8364f7c12e35b23ad               campinas
#
#     order_approved_at  year month
# 0 2017-05-16 15:22:12  2017    05
# 1 2018-01-12 20:58:32  2018    01
# 2 2018-05-20 16:19:10  2018    05
# 3 2018-03-13 17:29:19  2018    03
# 4 2018-07-29 10:10:09  2018    07

# %% [markdown]
# ## Customer City

# %%
dt_countcustmr = dt_ccyear.groupby(['year','customer_city'])['customer_id'].count().reset_index()
dt_countcustmr.head()
# Out:
#    year         customer_city  customer_id
# 0  2016          alem paraiba            1
# 1  2016            ananindeua            1
# 2  2016              anapolis            1
# 3  2016  aparecida de goiania            1
# 4  2016              apuarema            1

# %%
#dt_ccyear.groupby(['year','customer_city'])['customer_id'].count().plot.bar()
dt_countcustmr_2016 = dt_countcustmr[dt_countcustmr['year']=='2016']
dt_countcustmr_2016.head()
# Out:
#    year         customer_city  customer_id
# 0  2016          alem paraiba            1
# 1  2016            ananindeua            1
# 2  2016              anapolis            1
# 3  2016  aparecida de goiania            1
# 4  2016              apuarema            1

# %%
dt_countcustmr_2017 = dt_countcustmr[dt_countcustmr['year']=='2017']
dt_countcustmr_2017.head()
# Out:
#      year        customer_city  customer_id
# 177  2017  abadia dos dourados            1
# 178  2017               abaete            6
# 179  2017           abaetetuba            4
# 180  2017              abaiara            1
# 181  2017                abare            1

# %%
dt_countcustmr_2018 = dt_countcustmr[dt_countcustmr['year']=='2018']
dt_countcustmr_2018.head()
# Out:
#       year        customer_city  customer_id
# 3465  2018  abadia dos dourados            2
# 3466  2018            abadiania            1
# 3467  2018               abaete            5
# 3468  2018           abaetetuba            7
# 3469  2018              abaiara            1

# %%
mrk_area = dt_countcustmr_2016.groupby(['customer_city'])['customer_id'].sum().sort_values(ascending=False)[:10].reset_index()
mrk_area
# Out:
#     customer_city  customer_id
# 0       sao paulo           35
# 1  rio de janeiro           34
# 2  belo horizonte           12
# 3    porto alegre            7
# 4        campinas            7
# 5        curitiba            6
# 6        brasilia            6
# 7       fortaleza            5
# 8         goiania            5
# 9          recife            4

# %%
mrk_area1 = dt_countcustmr_2017.groupby(['customer_city'])['customer_id'].sum().sort_values(ascending=False)[:10].reset_index()
mrk_area1
# Out:
#            customer_city  customer_id
# 0              sao paulo         9112
# 1         rio de janeiro         3502
# 2         belo horizonte         1551
# 3               brasilia         1213
# 4               curitiba          863
# 5               campinas          816
# 6              guarulhos          695
# 7           porto alegre          679
# 8               salvador          676
# 9  sao bernardo do campo          537

# %%
mrk_area2 = dt_countcustmr_2018.groupby(['customer_city'])['customer_id'].sum().sort_values(ascending=False)[:10].reset_index()
mrk_area2
# Out:
#            customer_city  customer_id
# 0              sao paulo         9112
# 1         rio de janeiro         3502
# 2         belo horizonte         1551
# 3               brasilia         1213
# 4               curitiba          863
# 5               campinas          816
# 6              guarulhos          695
# 7           porto alegre          679
# 8               salvador          676
# 9  sao bernardo do campo          537

# %%
dt_countcustmr_2016.groupby(['customer_city'])['customer_id'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(20,7));

plt.xticks(rotation=60)
plt.ylabel('Total Customer');
plt.title('Top 10 Area Customer Interest On 2016');
plt.tight_layout()

# %%
dt_countcustmr_2017.groupby(['customer_city'])['customer_id'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(20,7));

plt.xticks(rotation=60)
plt.ylabel('Total Customer');
plt.title('Top 10 Area Customer Interest On 2017');
plt.tight_layout()

# %%
dt_countcustmr_2018.groupby(['customer_city'])['customer_id'].sum().sort_values(ascending=False)[:10].plot.bar(figsize=(20,7));

plt.xticks(rotation=60)
plt.ylabel('Total Customer');
plt.title('Top 10 Area Customer Interest On 2018');
plt.tight_layout()

# %% [markdown]
# ## Customer Payment Method

# %%
data2.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
data3.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
data5.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
dt_pymntmthd=data3[['order_id','payment_type']]
dt_pymntmthd.head()
# Out:
#                            order_id payment_type
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a  credit_card

# %%
dt_ordtmn=data5[['order_id','customer_id','order_approved_at']]
dt_ordtmn.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#      order_approved_at
# 0  2017-10-02 11:07:15
# 1  2018-07-26 03:24:27
# 2  2018-08-08 08:55:23
# 3  2017-11-18 19:45:59
# 4  2018-02-13 22:20:29

# %%
dt_or = pd.concat([dt_pymntmthd, dt_ordtmn],axis=1) #concat pandas digunakan untuk megeksport data , axis =1 digunakan untuk menampilkan masing2 kolom pada dataframe yang diexport secara berurut
dt_or.to_csv("order_approved_at.csv",index=False) #index=False, digunakan untuk membuat index baru atau menghilangkan multiple index

# %%
dford = pd.merge(dt_pymntmthd, dt_ordtmn,how='right') #left join
dford.head()
# Out:
#                            order_id payment_type  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  credit_card
# 1  e481f51cbdc54678b7cc49136f2d6af7      voucher
# 2  e481f51cbdc54678b7cc49136f2d6af7      voucher
# 3  53cdb2fc8bc7dce0b6741e2150273451       boleto
# 4  47770eb9100c2d0c44946d9cf07ec65d  credit_card
#
#                         customer_id    order_approved_at
# 0  9ef432eb6251297304e76186b10a928d  2017-10-02 11:07:15
# 1  9ef432eb6251297304e76186b10a928d  2017-10-02 11:07:15
# 2  9ef432eb6251297304e76186b10a928d  2017-10-02 11:07:15
# 3  b0830fb4747a6c6d20dea0b8c802d7ef  2018-07-26 03:24:27
# 4  41ce2a54c0b03bf3443c3d931a367089  2018-08-08 08:55:23

# %%
dford['order_approved_at']=pd.to_datetime(dt_ordtmn['order_approved_at']) #object data type convertion to datetime data type
dford.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103887 entries, 0 to 103886
# Data columns (total 4 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           103887 non-null  object
#  1   payment_type       103886 non-null  object
#  2   customer_id        103887 non-null  object
#  3   order_approved_at  99281 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 4.0+ MB

# %%
dford['year'] = dford['order_approved_at'].dt.strftime('%Y') # Split year and place it at order['year'] column
dford['month']=dford['order_approved_at'].dt.strftime('%m') # Split month and place it at order['month'] column

# %%
dford.head()
# Out:
#                            order_id payment_type  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  credit_card
# 1  e481f51cbdc54678b7cc49136f2d6af7      voucher
# 2  e481f51cbdc54678b7cc49136f2d6af7      voucher
# 3  53cdb2fc8bc7dce0b6741e2150273451       boleto
# 4  47770eb9100c2d0c44946d9cf07ec65d  credit_card
#
#                         customer_id   order_approved_at  year month
# 0  9ef432eb6251297304e76186b10a928d 2017-10-02 11:07:15  2017    10
# 1  9ef432eb6251297304e76186b10a928d 2018-07-26 03:24:27  2018    07
# 2  9ef432eb6251297304e76186b10a928d 2018-08-08 08:55:23  2018    08
# 3  b0830fb4747a6c6d20dea0b8c802d7ef 2017-11-18 19:45:59  2017    11
# 4  41ce2a54c0b03bf3443c3d931a367089 2018-02-13 22:20:29  2018    02

# %%
dttbl_ordtmn = pd.DataFrame(dford.groupby(['year','payment_type'])['customer_id'].count()).reset_index()
dttbl_ordtmn
# Out:
#     year payment_type  customer_id
# 0   2016       boleto           70
# 1   2016  credit_card          239
# 2   2016   debit_card            2
# 3   2016      voucher           11
# 4   2017       boleto         8565
# 5   2017  credit_card        33322
# 6   2017   debit_card          649
# 7   2017  not_defined            2
# 8   2017      voucher         2435
# 9   2018       boleto        10290
# 10  2018  credit_card        39841
# 11  2018   debit_card          817
# 12  2018  not_defined            1
# 13  2018      voucher         3036

# %%
dttbl_ordtmn.

# %%
dttbl_ordtmn_2016=dttbl_ordtmn[dttbl_ordtmn['year']=='2016']

# %%
dttbl_ordtmn_2016.groupby('payment_type')['customer_id'].sum().sort_values(ascending=False).plot.bar();

plt.xticks(rotation=60)
plt.ylabel('Total User');
plt.title('Payment Type User Preference 2016');
plt.tight_layout()

# %%
dttbl_ordtmn_2017=dttbl_ordtmn[dttbl_ordtmn['year']=='2017']
dttbl_ordtmn_2017.groupby('payment_type')['customer_id'].sum().sort_values(ascending=False).plot.bar()

plt.xticks(rotation=60)
plt.ylabel('Total User');
plt.title('Payment Type User Preference 2017');
plt.tight_layout()

# %%
dttbl_ordtmn_2018=dttbl_ordtmn[dttbl_ordtmn['year']=='2018']
dttbl_ordtmn_2018.groupby('payment_type')['customer_id'].sum().sort_values(ascending=False).plot.bar()

plt.xticks(rotation=60)
plt.ylabel('Total User');
plt.title('Payment Type User Preference 2018');
plt.tight_layout()
